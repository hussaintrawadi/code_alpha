# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv('NFLX.csv')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 0     11896100
# 1     12595800
# 2      8981500
# 3      9306700
# 4     16906900
# ...        ...
# 1004  20047500
# 1005  22542300
# 1006  14346000
# 1007   9905200
# 1008   7782400
#
# [1009 rows x 7 columns]

# %%
df = df[['Date','Close']]
df
# Out:
#             Date       Close
# 0     2018-02-05  254.259995
# 1     2018-02-06  265.720001
# 2     2018-02-07  264.559998
# 3     2018-02-08  250.100006
# 4     2018-02-09  249.470001
# ...          ...         ...
# 1004  2022-01-31  427.140015
# 1005  2022-02-01  457.130005
# 1006  2022-02-02  429.480011
# 1007  2022-02-03  405.600006
# 1008  2022-02-04  410.170013
#
# [1009 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1009 non-null   object
#  1   Close   1009 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 15.9+ KB

# %%
import datetime

def str_to_datetime(s):
    split = s.split("-")
    year, month, day = int(split[0]), int(split[1]), int(split[2])
    return datetime.datetime(year=year, month=month, day=day)

x = str_to_datetime('2018-02-05')
x
# Out:
# datetime.datetime(2018, 2, 5, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# C:\Users\hussa\AppData\Local\Temp\ipykernel_13876\2565755782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      2018-02-05
# 1      2018-02-06
# 2      2018-02-07
# 3      2018-02-08
# 4      2018-02-09
#           ...
# 1004   2022-01-31
# 1005   2022-02-01
# 1006   2022-02-02
# 1007   2022-02-03
# 1008   2022-02-04
# Name: Date, Length: 1009, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 2018-02-05  254.259995
# 2018-02-06  265.720001
# 2018-02-07  264.559998
# 2018-02-08  250.100006
# 2018-02-09  249.470001
# ...                ...
# 2022-01-31  427.140015
# 2022-02-01  457.130005
# 2022-02-02  429.480011
# 2022-02-03  405.600006
# 2022-02-04  410.170013
#
# [1009 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])
plt.xticks(rotation=45) 
plt.show()

# %%
def window_data(data, n=3):
    windowed_data = pd.DataFrame()
    for i in range(n, 0, -1):
        windowed_data[f'Target-{i}'] = data['Close'].shift(i)
    windowed_data['Target'] = data['Close']
    return windowed_data.dropna()

# %%
df = window_data(df)

# %%
df.head()
# Out:
#               Target-3    Target-2    Target-1      Target
# Date
# 2018-02-08  254.259995  265.720001  264.559998  250.100006
# 2018-02-09  265.720001  264.559998  250.100006  249.470001
# 2018-02-12  264.559998  250.100006  249.470001  257.950012
# 2018-02-13  250.100006  249.470001  257.950012  258.269989
# 2018-02-14  249.470001  257.950012  258.269989  266.000000

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
    
    df_as_np = windowed_dataframe.to_numpy()
#    dates = df_as_np.index()

    middle_matrix = df_as_np[:, :-1]
    X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

    Y = df_as_np[:, -1]

    return X.astype(np.float32), Y.astype(np.float32)

dates = df.index

X, y = windowed_df_to_date_X_y(df)
dates.shape, X.shape, y.shape
# Out:
# ((1006,), (1006, 3, 1), (1006,))

# %%
dates
# Out:
# DatetimeIndex(['2018-02-08', '2018-02-09', '2018-02-12', '2018-02-13',
#                '2018-02-14', '2018-02-15', '2018-02-16', '2018-02-20',
#                '2018-02-21', '2018-02-22',
#                ...
#                '2022-01-24', '2022-01-25', '2022-01-26', '2022-01-27',
#                '2022-01-28', '2022-01-31', '2022-02-01', '2022-02-02',
#                '2022-02-03', '2022-02-04'],
#               dtype='datetime64[ns]', name='Date', length=1006, freq=None)

# %%
X.shape, y.shape
# Out:
# ((1006, 3, 1), (1006,))

# %%
dates = np.array(dates)

# %%
print(dates)
print()
print(dates.shape)
# Out:
# ['2018-02-08T00:00:00.000000000' '2018-02-09T00:00:00.000000000'
#  '2018-02-12T00:00:00.000000000' ... '2022-02-02T00:00:00.000000000'
#  '2022-02-03T00:00:00.000000000' '2022-02-04T00:00:00.000000000']
#
# (1006,)

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

# Train Data
dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

# Validation Data
dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]

# Test Data
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

# %%
plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.xticks(rotation=45)

plt.legend(['Train', 'Validation', 'Test'])
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.layers import LSTM, Dense

# %%
model = Sequential()
model.add(LSTM(72, input_shape=(3,1)))

model.add(Dense(32,'relu'))

model.add(Dense(16,'relu'))

model.add(Dense(8,'relu'))

model.add(Dense(4,'relu'))

model.add(Dense(1,'linear'))

model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\hussa\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 72)                21312
#
#  dense (Dense)               (None, 32)                2336
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 4)                 36
#
#  dense_4 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 24353 (95.13 KB)
# Trainable params: 24353 (95.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='mse',optimizer=Adam(learning_rate=0.001),metrics=['mean_absolute_error'])

# %%
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=120)
# Out:
# Epoch 1/120
# WARNING:tensorflow:From C:\Users\hussa\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\hussa\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 26/26 [==============================] - 11s 85ms/step - loss: 155269.1094 - mean_absolute_error: 384.5876 - val_loss: 272186.1250 - val_mean_absolute_error: 520.9076
# Epoch 2/120
# 26/26 [==============================] - 0s 14ms/step - loss: 154921.4375 - mean_absolute_error: 384.1345 - val_loss: 271378.1875 - val_mean_absolute_error: 520.1315
# Epoch 3/120
# 26/26 [==============================] - 0s 14ms/step - loss: 153770.3750 - mean_absolute_error: 382.6339 - val_loss: 268718.6250 - val_mean_absolute_error: 517.5683
# Epoch 4/120
# 26/26 [==============================] - 0s 13ms/step - loss: 149990.2031 - mean_absolute_error: 377.6845 - val_loss: 260029.7812 - val_mean_absolute_error: 509.1053
# Epoch 5/120
# 26/26 [==============================] - 0s 13ms/step - loss: 139749.9844 - mean_absolute_error: 363.8678 - val_loss: 237574.5938 - val_mean_absolute_error: 486.5515
# Epoch 6/120
# 26/26 [==============================] - 0s 14ms/step - loss: 116945.7422 - mean_absolute_error: 330.8526 - val_loss: 193950.1406 - val_mean_absolute_error: 439.4413
# Epoch 7/120
# 26/26 [==============================] - 0s 14ms/step - loss: 79322.5156 - mean_absolute_error: 267.4602 - val_loss: 127594.3359 - val_mean_absolute_error: 356.0236
# Epoch 8/120
# 26/26 [==============================] - 0s 14ms/step - loss: 36300.9688 - mean_absolute_error: 167.3332 - val_loss: 57832.2891 - val_mean_absolute_error: 238.7243
# Epoch 9/120
# 26/26 [==============================] - 0s 14ms/step - loss: 10525.3223 - mean_absolute_error: 75.7036 - val_loss: 22019.5312 - val_mean_absolute_error: 145.5268
# Epoch 10/120
# 26/26 [==============================] - 0s 14ms/step - loss: 7487.4160 - mean_absolute_error: 74.5680 - val_loss: 17325.7988 - val_mean_absolute_error: 128.3913
# Epoch 11/120
# 26/26 [==============================] - 0s 14ms/step - loss: 7252.6431 - mean_absolute_error: 71.6126 - val_loss: 19687.1875 - val_mean_absolute_error: 137.3145
# Epoch 12/120
# 26/26 [==============================] - 0s 14ms/step - loss: 6384.1406 - mean_absolute_error: 64.3901 - val_loss: 19236.6387 - val_mean_absolute_error: 136.0134
# Epoch 13/120
# 26/26 [==============================] - 0s 13ms/step - loss: 5205.5283 - mean_absolute_error: 58.4254 - val_loss: 13256.0186 - val_mean_absolute_error: 112.0347
# Epoch 14/120
# 26/26 [==============================] - 0s 14ms/step - loss: 3654.9292 - mean_absolute_error: 48.1855 - val_loss: 8539.4062 - val_mean_absolute_error: 88.6289
# Epoch 15/120
# 26/26 [==============================] - 0s 14ms/step - loss: 1915.1465 - mean_absolute_error: 32.5846 - val_loss: 4502.2085 - val_mean_absolute_error: 62.2665
# Epoch 16/120
# 26/26 [==============================] - 0s 15ms/step - loss: 782.5204 - mean_absolute_error: 19.2267 - val_loss: 1811.4935 - val_mean_absolute_error: 35.0179
# Epoch 17/120
# 26/26 [==============================] - 0s 14ms/step - loss: 396.3388 - mean_absolute_error: 14.3212 - val_loss: 927.8452 - val_mean_absolute_error: 21.1390
# Epoch 18/120
# 26/26 [==============================] - 0s 14ms/step - loss: 265.4640 - mean_absolute_error: 12.0390 - val_loss: 641.0988 - val_mean_absolute_error: 16.7845
# Epoch 19/120
# 26/26 [==============================] - 0s 14ms/step - loss: 196.4021 - mean_absolute_error: 10.1350 - val_loss: 489.3724 - val_mean_absolute_error: 14.3194
# Epoch 20/120
# 26/26 [==============================] - 0s 16ms/step - loss: 212.8388 - mean_absolute_error: 11.2549 - val_loss: 470.2474 - val_mean_absolute_error: 14.0345
# Epoch 21/120
# 26/26 [==============================] - 0s 14ms/step - loss: 171.4273 - mean_absolute_error: 9.8502 - val_loss: 375.7274 - val_mean_absolute_error: 13.4527
# Epoch 22/120
# 26/26 [==============================] - 0s 14ms/step - loss: 165.5270 - mean_absolute_error: 9.7512 - val_loss: 406.5232 - val_mean_absolute_error: 13.3605
# Epoch 23/120
# 26/26 [==============================] - 0s 14ms/step - loss: 144.7345 - mean_absolute_error: 8.6391 - val_loss: 319.3031 - val_mean_absolute_error: 11.6911
# Epoch 24/120
# 26/26 [==============================] - 0s 14ms/step - loss: 147.2672 - mean_absolute_error: 9.0260 - val_loss: 298.8584 - val_mean_absolute_error: 11.4986
# Epoch 25/120
# 26/26 [==============================] - 0s 14ms/step - loss: 142.5930 - mean_absolute_error: 8.8457 - val_loss: 316.0186 - val_mean_absolute_error: 11.6636
# Epoch 26/120
# 26/26 [==============================] - 0s 14ms/step - loss: 148.6017 - mean_absolute_error: 9.2184 - val_loss: 270.0114 - val_mean_absolute_error: 10.7484
# Epoch 27/120
# 26/26 [==============================] - 0s 14ms/step - loss: 129.8770 - mean_absolute_error: 8.3344 - val_loss: 257.9818 - val_mean_absolute_error: 10.4774
# Epoch 28/120
# 26/26 [==============================] - 0s 14ms/step - loss: 125.9061 - mean_absolute_error: 8.1824 - val_loss: 309.3220 - val_mean_absolute_error: 12.2425
# Epoch 29/120
# 26/26 [==============================] - 0s 14ms/step - loss: 140.6677 - mean_absolute_error: 8.6581 - val_loss: 370.1521 - val_mean_absolute_error: 14.6800
# Epoch 30/120
# 26/26 [==============================] - 0s 15ms/step - loss: 144.0875 - mean_absolute_error: 8.9373 - val_loss: 230.4272 - val_mean_absolute_error: 9.9819
# Epoch 31/120
# 26/26 [==============================] - 0s 14ms/step - loss: 123.1207 - mean_absolute_error: 8.0555 - val_loss: 220.6848 - val_mean_absolute_error: 9.7469
# Epoch 32/120
# 26/26 [==============================] - 0s 14ms/step - loss: 122.6555 - mean_absolute_error: 8.0416 - val_loss: 212.4058 - val_mean_absolute_error: 9.7524
# Epoch 33/120
# 26/26 [==============================] - 0s 15ms/step - loss: 142.6816 - mean_absolute_error: 8.8963 - val_loss: 357.0180 - val_mean_absolute_error: 14.6552
# Epoch 34/120
# 26/26 [==============================] - 0s 14ms/step - loss: 165.1763 - mean_absolute_error: 9.9964 - val_loss: 227.9781 - val_mean_absolute_error: 9.7878
# Epoch 35/120
# 26/26 [==============================] - 0s 14ms/step - loss: 128.6616 - mean_absolute_error: 8.3939 - val_loss: 231.0470 - val_mean_absolute_error: 11.2125
# Epoch 36/120
# 26/26 [==============================] - 0s 16ms/step - loss: 129.0973 - mean_absolute_error: 8.4390 - val_loss: 212.2876 - val_mean_absolute_error: 9.6687
# Epoch 37/120
# 26/26 [==============================] - 0s 16ms/step - loss: 157.6583 - mean_absolute_error: 9.3932 - val_loss: 208.6087 - val_mean_absolute_error: 10.0092
# Epoch 38/120
# 26/26 [==============================] - 0s 16ms/step - loss: 128.6096 - mean_absolute_error: 8.3590 - val_loss: 207.0519 - val_mean_absolute_error: 9.2726
# Epoch 39/120
# 26/26 [==============================] - 0s 16ms/step - loss: 123.0081 - mean_absolute_error: 8.0330 - val_loss: 201.9726 - val_mean_absolute_error: 9.6993
# Epoch 40/120
# 26/26 [==============================] - 0s 14ms/step - loss: 118.3313 - mean_absolute_error: 7.8533 - val_loss: 213.2597 - val_mean_absolute_error: 10.8261
# Epoch 41/120
# 26/26 [==============================] - 0s 14ms/step - loss: 123.6721 - mean_absolute_error: 8.1535 - val_loss: 190.5244 - val_mean_absolute_error: 9.4227
# Epoch 42/120
# 26/26 [==============================] - 0s 14ms/step - loss: 124.4318 - mean_absolute_error: 8.1502 - val_loss: 273.4452 - val_mean_absolute_error: 13.7552
# Epoch 43/120
# 26/26 [==============================] - 0s 14ms/step - loss: 117.5331 - mean_absolute_error: 7.8058 - val_loss: 200.2758 - val_mean_absolute_error: 10.5322
# Epoch 44/120
# 26/26 [==============================] - 0s 14ms/step - loss: 124.9900 - mean_absolute_error: 8.2858 - val_loss: 321.0176 - val_mean_absolute_error: 14.4278
# Epoch 45/120
# 26/26 [==============================] - 0s 15ms/step - loss: 151.2953 - mean_absolute_error: 9.2616 - val_loss: 190.9556 - val_mean_absolute_error: 9.2935
# Epoch 46/120
# 26/26 [==============================] - 0s 15ms/step - loss: 115.8505 - mean_absolute_error: 7.8423 - val_loss: 201.7079 - val_mean_absolute_error: 9.2248
# Epoch 47/120
# 26/26 [==============================] - 0s 15ms/step - loss: 145.2853 - mean_absolute_error: 9.1192 - val_loss: 193.7010 - val_mean_absolute_error: 9.0986
# Epoch 48/120
# 26/26 [==============================] - 0s 14ms/step - loss: 122.7522 - mean_absolute_error: 8.1793 - val_loss: 175.8757 - val_mean_absolute_error: 8.6288
# Epoch 49/120
# 26/26 [==============================] - 0s 15ms/step - loss: 117.0898 - mean_absolute_error: 7.9440 - val_loss: 383.5548 - val_mean_absolute_error: 16.4058
# Epoch 50/120
# 26/26 [==============================] - 0s 14ms/step - loss: 153.7537 - mean_absolute_error: 9.3265 - val_loss: 246.3447 - val_mean_absolute_error: 12.8975
# Epoch 51/120
# 26/26 [==============================] - 0s 16ms/step - loss: 116.7343 - mean_absolute_error: 7.8842 - val_loss: 194.2098 - val_mean_absolute_error: 9.2960
# Epoch 52/120
# 26/26 [==============================] - 0s 15ms/step - loss: 122.5900 - mean_absolute_error: 8.1222 - val_loss: 165.6794 - val_mean_absolute_error: 8.4462
# Epoch 53/120
# 26/26 [==============================] - 0s 15ms/step - loss: 118.4225 - mean_absolute_error: 7.9700 - val_loss: 238.7928 - val_mean_absolute_error: 11.5262
# Epoch 54/120
# 26/26 [==============================] - 0s 15ms/step - loss: 134.7153 - mean_absolute_error: 8.4554 - val_loss: 184.7072 - val_mean_absolute_error: 9.0360
# Epoch 55/120
# 26/26 [==============================] - 0s 14ms/step - loss: 154.6073 - mean_absolute_error: 9.3339 - val_loss: 217.6711 - val_mean_absolute_error: 10.4554
# Epoch 56/120
# 26/26 [==============================] - 0s 14ms/step - loss: 132.5332 - mean_absolute_error: 8.4872 - val_loss: 182.8119 - val_mean_absolute_error: 9.9427
# Epoch 57/120
# 26/26 [==============================] - 0s 15ms/step - loss: 138.0790 - mean_absolute_error: 8.8278 - val_loss: 195.2802 - val_mean_absolute_error: 9.4685
# Epoch 58/120
# 26/26 [==============================] - 0s 15ms/step - loss: 125.4890 - mean_absolute_error: 8.2391 - val_loss: 393.7546 - val_mean_absolute_error: 17.8634
# Epoch 59/120
# 26/26 [==============================] - 0s 15ms/step - loss: 182.1847 - mean_absolute_error: 10.3782 - val_loss: 209.6015 - val_mean_absolute_error: 9.4709
# Epoch 60/120
# 26/26 [==============================] - 0s 14ms/step - loss: 118.0055 - mean_absolute_error: 7.8998 - val_loss: 221.7892 - val_mean_absolute_error: 10.4216
# Epoch 61/120
# 26/26 [==============================] - 0s 15ms/step - loss: 137.1127 - mean_absolute_error: 8.9143 - val_loss: 184.8189 - val_mean_absolute_error: 10.0288
# Epoch 62/120
# 26/26 [==============================] - 0s 15ms/step - loss: 129.3009 - mean_absolute_error: 8.3390 - val_loss: 240.4187 - val_mean_absolute_error: 11.5799
# Epoch 63/120
# 26/26 [==============================] - 0s 14ms/step - loss: 124.0894 - mean_absolute_error: 8.1860 - val_loss: 159.7740 - val_mean_absolute_error: 8.3611
# Epoch 64/120
# 26/26 [==============================] - 0s 15ms/step - loss: 119.6614 - mean_absolute_error: 7.8885 - val_loss: 157.1744 - val_mean_absolute_error: 8.2048
# Epoch 65/120
# 26/26 [==============================] - 0s 14ms/step - loss: 124.2277 - mean_absolute_error: 8.2869 - val_loss: 166.9727 - val_mean_absolute_error: 8.6800
# Epoch 66/120
# 26/26 [==============================] - 0s 15ms/step - loss: 124.3692 - mean_absolute_error: 8.3883 - val_loss: 378.5426 - val_mean_absolute_error: 17.5671
# Epoch 67/120
# 26/26 [==============================] - 0s 14ms/step - loss: 139.8280 - mean_absolute_error: 8.7304 - val_loss: 243.5925 - val_mean_absolute_error: 13.1677
# Epoch 68/120
# 26/26 [==============================] - 0s 14ms/step - loss: 145.2230 - mean_absolute_error: 8.8164 - val_loss: 234.5861 - val_mean_absolute_error: 11.4156
# Epoch 69/120
# 26/26 [==============================] - 0s 14ms/step - loss: 153.1942 - mean_absolute_error: 9.2602 - val_loss: 169.5516 - val_mean_absolute_error: 8.4874
# Epoch 70/120
# 26/26 [==============================] - 0s 14ms/step - loss: 157.4257 - mean_absolute_error: 9.6828 - val_loss: 197.5843 - val_mean_absolute_error: 9.1391
# Epoch 71/120
# 26/26 [==============================] - 0s 14ms/step - loss: 117.3660 - mean_absolute_error: 7.9071 - val_loss: 205.6653 - val_mean_absolute_error: 9.5912
# Epoch 72/120
# 26/26 [==============================] - 0s 14ms/step - loss: 126.8172 - mean_absolute_error: 8.1905 - val_loss: 169.4615 - val_mean_absolute_error: 9.1478
# Epoch 73/120
# 26/26 [==============================] - 0s 14ms/step - loss: 115.0526 - mean_absolute_error: 7.8632 - val_loss: 236.3556 - val_mean_absolute_error: 12.7616
# Epoch 74/120
# 26/26 [==============================] - 0s 14ms/step - loss: 122.6941 - mean_absolute_error: 8.1668 - val_loss: 187.7585 - val_mean_absolute_error: 10.5571
# Epoch 75/120
# 26/26 [==============================] - 0s 14ms/step - loss: 135.4545 - mean_absolute_error: 8.8423 - val_loss: 219.1958 - val_mean_absolute_error: 12.1363
# Epoch 76/120
# 26/26 [==============================] - 0s 14ms/step - loss: 143.4768 - mean_absolute_error: 8.7130 - val_loss: 170.2240 - val_mean_absolute_error: 8.9575
# Epoch 77/120
# 26/26 [==============================] - 0s 14ms/step - loss: 124.8416 - mean_absolute_error: 8.1151 - val_loss: 171.8216 - val_mean_absolute_error: 8.5664
# Epoch 78/120
# 26/26 [==============================] - 0s 13ms/step - loss: 117.3331 - mean_absolute_error: 7.8767 - val_loss: 181.1745 - val_mean_absolute_error: 9.1306
# Epoch 79/120
# 26/26 [==============================] - 0s 15ms/step - loss: 131.3858 - mean_absolute_error: 8.4033 - val_loss: 177.2458 - val_mean_absolute_error: 10.1893
# Epoch 80/120
# 26/26 [==============================] - 0s 14ms/step - loss: 113.5722 - mean_absolute_error: 7.6460 - val_loss: 167.0683 - val_mean_absolute_error: 9.2556
# Epoch 81/120
# 26/26 [==============================] - 0s 13ms/step - loss: 124.7618 - mean_absolute_error: 8.1723 - val_loss: 198.9118 - val_mean_absolute_error: 11.1329
# Epoch 82/120
# 26/26 [==============================] - 0s 15ms/step - loss: 135.3492 - mean_absolute_error: 8.5438 - val_loss: 218.9185 - val_mean_absolute_error: 11.9281
# Epoch 83/120
# 26/26 [==============================] - 0s 13ms/step - loss: 142.4477 - mean_absolute_error: 8.9663 - val_loss: 165.6887 - val_mean_absolute_error: 8.6260
# Epoch 84/120
# 26/26 [==============================] - 0s 15ms/step - loss: 120.6381 - mean_absolute_error: 8.0053 - val_loss: 210.8364 - val_mean_absolute_error: 11.7285
# Epoch 85/120
# 26/26 [==============================] - 0s 15ms/step - loss: 147.0284 - mean_absolute_error: 8.9003 - val_loss: 176.2549 - val_mean_absolute_error: 8.6986
# Epoch 86/120
# 26/26 [==============================] - 0s 14ms/step - loss: 121.7056 - mean_absolute_error: 8.0209 - val_loss: 178.1503 - val_mean_absolute_error: 10.0601
# Epoch 87/120
# 26/26 [==============================] - 0s 14ms/step - loss: 137.9420 - mean_absolute_error: 8.5508 - val_loss: 161.1548 - val_mean_absolute_error: 8.4734
# Epoch 88/120
# 26/26 [==============================] - 0s 16ms/step - loss: 117.5153 - mean_absolute_error: 7.8905 - val_loss: 168.1951 - val_mean_absolute_error: 9.3353
# Epoch 89/120
# 26/26 [==============================] - 0s 14ms/step - loss: 132.9559 - mean_absolute_error: 8.4085 - val_loss: 381.2037 - val_mean_absolute_error: 16.9359
# Epoch 90/120
# 26/26 [==============================] - 0s 15ms/step - loss: 163.6728 - mean_absolute_error: 9.6538 - val_loss: 178.4393 - val_mean_absolute_error: 9.6062
# Epoch 91/120
# 26/26 [==============================] - 0s 13ms/step - loss: 122.4442 - mean_absolute_error: 8.1770 - val_loss: 168.4176 - val_mean_absolute_error: 8.6076
# Epoch 92/120
# 26/26 [==============================] - 0s 14ms/step - loss: 143.4653 - mean_absolute_error: 8.9550 - val_loss: 241.4131 - val_mean_absolute_error: 13.0269
# Epoch 93/120
# 26/26 [==============================] - 0s 14ms/step - loss: 130.4435 - mean_absolute_error: 8.3729 - val_loss: 165.0237 - val_mean_absolute_error: 8.8102
# Epoch 94/120
# 26/26 [==============================] - 0s 15ms/step - loss: 131.9820 - mean_absolute_error: 8.3611 - val_loss: 222.6114 - val_mean_absolute_error: 10.8780
# Epoch 95/120
# 26/26 [==============================] - 0s 14ms/step - loss: 169.4629 - mean_absolute_error: 9.8345 - val_loss: 165.9814 - val_mean_absolute_error: 8.3758
# Epoch 96/120
# 26/26 [==============================] - 0s 14ms/step - loss: 146.4170 - mean_absolute_error: 9.1392 - val_loss: 227.6488 - val_mean_absolute_error: 12.3311
# Epoch 97/120
# 26/26 [==============================] - 0s 14ms/step - loss: 119.8694 - mean_absolute_error: 7.9302 - val_loss: 179.7460 - val_mean_absolute_error: 9.9494
# Epoch 98/120
# 26/26 [==============================] - 0s 15ms/step - loss: 127.2256 - mean_absolute_error: 8.2484 - val_loss: 208.6697 - val_mean_absolute_error: 11.5808
# Epoch 99/120
# 26/26 [==============================] - 0s 14ms/step - loss: 128.6699 - mean_absolute_error: 8.3750 - val_loss: 162.9804 - val_mean_absolute_error: 8.7433
# Epoch 100/120
# 26/26 [==============================] - 0s 15ms/step - loss: 130.9693 - mean_absolute_error: 8.3743 - val_loss: 157.3603 - val_mean_absolute_error: 8.5419
# Epoch 101/120
# 26/26 [==============================] - 0s 16ms/step - loss: 114.5487 - mean_absolute_error: 7.6267 - val_loss: 154.5893 - val_mean_absolute_error: 8.5307
# Epoch 102/120
# 26/26 [==============================] - 0s 15ms/step - loss: 125.2093 - mean_absolute_error: 8.1463 - val_loss: 155.6934 - val_mean_absolute_error: 8.2400
# Epoch 103/120
# 26/26 [==============================] - 0s 15ms/step - loss: 118.6035 - mean_absolute_error: 7.9482 - val_loss: 154.2472 - val_mean_absolute_error: 8.2080
# Epoch 104/120
# 26/26 [==============================] - 0s 15ms/step - loss: 148.1791 - mean_absolute_error: 9.0987 - val_loss: 171.5195 - val_mean_absolute_error: 9.1069
# Epoch 105/120
# 26/26 [==============================] - 0s 14ms/step - loss: 142.7026 - mean_absolute_error: 8.9100 - val_loss: 313.3238 - val_mean_absolute_error: 15.4025
# Epoch 106/120
# 26/26 [==============================] - 0s 14ms/step - loss: 143.6375 - mean_absolute_error: 9.0025 - val_loss: 213.5919 - val_mean_absolute_error: 9.5537
# Epoch 107/120
# 26/26 [==============================] - 0s 13ms/step - loss: 132.6501 - mean_absolute_error: 8.4503 - val_loss: 188.5543 - val_mean_absolute_error: 9.5951
# Epoch 108/120
# 26/26 [==============================] - 0s 14ms/step - loss: 127.8533 - mean_absolute_error: 8.4058 - val_loss: 173.6850 - val_mean_absolute_error: 8.5653
# Epoch 109/120
# 26/26 [==============================] - 0s 14ms/step - loss: 128.3469 - mean_absolute_error: 8.2050 - val_loss: 234.5586 - val_mean_absolute_error: 12.5454
# Epoch 110/120
# 26/26 [==============================] - 0s 14ms/step - loss: 136.0691 - mean_absolute_error: 8.6356 - val_loss: 183.0048 - val_mean_absolute_error: 9.8692
# Epoch 111/120
# 26/26 [==============================] - 0s 14ms/step - loss: 122.0154 - mean_absolute_error: 8.0381 - val_loss: 168.8073 - val_mean_absolute_error: 8.5299
# Epoch 112/120
# 26/26 [==============================] - 0s 14ms/step - loss: 125.9578 - mean_absolute_error: 8.1997 - val_loss: 176.3188 - val_mean_absolute_error: 10.0658
# Epoch 113/120
# 26/26 [==============================] - 0s 15ms/step - loss: 135.1235 - mean_absolute_error: 8.6026 - val_loss: 218.8832 - val_mean_absolute_error: 11.8614
# Epoch 114/120
# 26/26 [==============================] - 0s 15ms/step - loss: 114.6160 - mean_absolute_error: 7.6890 - val_loss: 174.5773 - val_mean_absolute_error: 9.4840
# Epoch 115/120
# 26/26 [==============================] - 0s 15ms/step - loss: 115.3292 - mean_absolute_error: 7.7523 - val_loss: 180.9465 - val_mean_absolute_error: 9.1337
# Epoch 116/120
# 26/26 [==============================] - 0s 14ms/step - loss: 114.0273 - mean_absolute_error: 7.6703 - val_loss: 196.7909 - val_mean_absolute_error: 9.9528
# Epoch 117/120
# 26/26 [==============================] - 0s 15ms/step - loss: 125.0401 - mean_absolute_error: 8.0887 - val_loss: 149.9199 - val_mean_absolute_error: 8.0288
# Epoch 118/120
# 26/26 [==============================] - 0s 14ms/step - loss: 114.6595 - mean_absolute_error: 7.6427 - val_loss: 177.2974 - val_mean_absolute_error: 10.2939
# Epoch 119/120
# 26/26 [==============================] - 0s 14ms/step - loss: 127.4456 - mean_absolute_error: 8.3693 - val_loss: 176.0287 - val_mean_absolute_error: 8.7157
# Epoch 120/120
# 26/26 [==============================] - 0s 15ms/step - loss: 117.5636 - mean_absolute_error: 7.8860 - val_loss: 170.8325 - val_mean_absolute_error: 9.7920

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)

plt.xticks(rotation=45)
plt.legend(['Training Predictions', 'Training Observations'])
plt.show()
# Out:
# 26/26 [==============================] - 2s 6ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)

plt.xticks(rotation=45)
plt.legend(['Validation Predictions', 'Validation Observations'])
plt.show()
# Out:
# 4/4 [==============================] - 0s 7ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)

plt.xticks(rotation=45)
plt.legend(['Testing Predictions', 'Testing Observations'])
plt.show()
# Out:
# 4/4 [==============================] - 0s 5ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)

plt.xticks(rotation=45)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])
plt.show()

# %% [markdown]
# Now we will try to predict the stock prices without the actual data, starting from the validation_data till the test_data and Evaluate the result

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
    last_window = deepcopy(X_train[-1])
    next_prediction = model.predict(np.array([last_window])).flatten()
    recursive_predictions.append(next_prediction)
    last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 63ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)

plt.xticks(rotation=45)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])
plt.show()

# %% [markdown]
# The Pink Line indicates the prediction without any data, i.e. we are starting from the known date (last date of val_data) and trying to predict future stock prices from there with help of our LSTM Model
